# %% [markdown]
# # Que es un arbol
#
#
# ## ¿Qué es un bosques?
# Es un grafo no dirigido y no necesariamente es conexo pero si tiene muchos componentes conectados
#
#
#
#
# ## Tipos de vértices
#
# - Raíz es el nodo superior
# - Nodo hijo
#     Depende de otro pero tiene otro por debajo quie depende de el
# - Nodo hoja
#     Es un nodo que no tiene hijos
#
#
# - Ancestro
#     Es un camino hacia arriba
# - Desendientes
#     Camino hacia abajo
#
# # Desiciones en IA
#
#
#
# # Tipos de arboles
# Árboles:
# - AVL
# - B

# %%
class Node:
    def __init__(
        self, nombre="Sin nombre", dadN=None, childL=None, childD=None, root=False
    ):
        self.validation(dadN)
        self.validation(childL)
        self.validation(childD)
        self.nombre = nombre
        self.node_dad = dadN
        self.node_child_left = childL
        self.node_child_right = childD
        self.am_i_root = root

    def validation(self, node):
        if node is not None and not isinstance(node, Node):
            raise TypeError("dadN debe ser una instancia de Node o None")

    def add_left_child(self, child_node):
        """LEEEEEEFTTTTT 👈🏼"""
        
        self.validation(child_node)
        # add dad
        child_node.add_dad(self)
        self.node_child_left = child_node

    def add_right_child(self, child_node):
        """RIGHTTTTTTTTTT 👉🏼"""
        
        self.validation(child_node)
        # add dad
        child_node.add_dad(self)
        self.node_child_right = child_node

    def add_dad(self, dad_node):
        self.validation(dad_node)

        # Tnego papa?
        if not self.node_dad:
            self.node_dad = dad_node

    def get_node_info(self):
        dad = self.node_dad
        childL = self.node_child_left
        childD = self.node_child_right
        return dad, childL, childD
    
    def __str__(self):
        text = f"""
        Nombre: {self.nombre}
        Root: {self.am_i_root}
        Dad: {self.node_dad.nombre if self.node_dad else None}
        Child Left: {self.node_child_left.nombre if self.node_child_left else None}
        Child Right: {self.node_child_right.nombre if self.node_child_right else None}
        """
        return text

# %%
ARBOL = {
    "a": ["b", "c"],
    "b": ["d", "e"],
    "d": [None, None],
    "e": [None, None],
    "c": [None, "f"],
    "f": [None, None],
}

def creador_nodos(numero_nodos):
    lista_nodos = [Node() for _ in range(numero_nodos)]
    return lista_nodos

# %%
total_nodos = len(ARBOL.items())
lista_nodos = creador_nodos(total_nodos)
for nodo in lista_nodos:
    print(nodo)
# Out:
#         Nombre: Sin nombre
#         Root: False
#         Dad: None
#         Child Left: None
#         Child Right: None
#
#
#         Nombre: Sin nombre
#         Root: False
#         Dad: None
#         Child Left: None
#         Child Right: None
#
#
#         Nombre: Sin nombre
#         Root: False
#         Dad: None
#         Child Left: None
#         Child Right: None
#
#
#         Nombre: Sin nombre
#         Root: False
#         Dad: None
#         Child Left: None
#         Child Right: None
#
#
#         Nombre: Sin nombre
#         Root: False
#         Dad: None
#         Child Left: None
#         Child Right: None
#
#
#         Nombre: Sin nombre
#         Root: False
#         Dad: None
#         Child Left: None
#         Child Right: None

# %%
for i,(nodo,conexiones_nodo) in enumerate(ARBOL.items()):
    node = lista_nodos[i]
    node.nombre= nodo
    print(nodo)
# Out:
# a
# b
# d
# e
# c
# f

# %%
def find_node(lista_nodos, nombre):
    for nodo in lista_nodos:
        if nodo.nombre == nombre:
            return nodo
    return None

# %%
for i,(nodo,conexiones_nodo) in enumerate(ARBOL.items()):
    node = lista_nodos[i]
    nodo_hijo_izq = find_node(lista_nodos, conexiones_nodo[0])
    nodo_hijo_der = find_node(lista_nodos, conexiones_nodo[1])
    if i ==0:
        node.am_i_root = True
    if nodo_hijo_izq:
        node.add_left_child(nodo_hijo_izq)
    if nodo_hijo_der:
        node.add_right_child(nodo_hijo_der)

# %%
for nodo in lista_nodos:
    print(nodo)
    print("----")
# Out:
#         Nombre: a
#         Root: True
#         Dad: None
#         Child Left: b
#         Child Right: c
#
# ----
#
#         Nombre: b
#         Root: False
#         Dad: a
#         Child Left: d
#         Child Right: e
#
# ----
#
#         Nombre: d
#         Root: False
#         Dad: b
#         Child Left: None
#         Child Right: None
#
# ----
#
#         Nombre: e
#         Root: False
#         Dad: b
#         Child Left: None
#         Child Right: None
#
# ----
#
#         Nombre: c
#         Root: False
#         Dad: a
#         Child Left: None
#         Child Right: f
#
# ----
#
#         Nombre: f
#         Root: False
#         Dad: c
#         Child Left: None
#         Child Right: None
#
# ----
